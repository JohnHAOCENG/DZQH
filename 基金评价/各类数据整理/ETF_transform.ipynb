# %%
import os
import time
from functools import reduce
import numpy as np
import pandas as pd

# %%
load_data = pd.read_excel("基金前十持有人.xlsx",  usecols="A,B,C,D,E,F,G,H,I,J,K,L,M")
load_data
# Out:
#            证券代码               证券简称                     第1名持有人名称  \
# 0     160125.OF             南方香港优选                           左群
# 1     165521.OF       中信保诚中证800金融A                           邹建
# 2     161124.OF      易方达香港恒生综合小型股A                 株洲结谷实业有限责任公司
# 3     160416.OF          华安标普全球石油A                 株洲结谷实业有限责任公司
# 4     501302.OF         南方恒生ETF联接A                          朱晓颖
# ...         ...                ...                          ...
# 1269  160219.OF          国泰国证医药卫生A                           班宽
# 1270  513200.OF  易方达中证港股通医药卫生综合ETF          百年人寿保险股份有限公司-传统保险产品
# 1271  516820.OF   平安中证医药及医疗器械创新ETF  百年保险资管-南京银行-百年资管弘远11号资产管理产品
# 1272        NaN                NaN                          NaN
# 1273  数据来源：Wind                NaN                          NaN
#
#                                    第2名持有人名称           第3名持有人名称  \
# 0                                       罗远芬                夏志元
# 1                                        孙毅                韦桂生
# 2                                        娄钧                 曹莉
# 3     北京新湖巨源投资管理有限公司-新湖巨源泓湖百世风险平衡1号私募证券投资基金                张汝愉
# 4                                       湛胜仁       深圳市老龄事业发展基金会
# ...                                     ...                ...
# 1269                                     乔劲                 杨碧
# 1270                           新华人寿保险股份有限公司  信泰人寿保险股份有限公司-分红产品
# 1271                          青岛云锦新能源科技有限公司                林生铃
# 1272                                    NaN                NaN
# 1273                                    NaN                NaN
#
#              第4名持有人名称                                          第5名持有人名称  \
# 0                 邵常红                                               王安民
# 1                 殷丽贞                                                叶宁
# 2                 夏桂玉                                                胡欣
# 3                 李永东                                               尹大力
# 4                 邵常红                                               骆念春
# ...               ...                                               ...
# 1269              陈南方                                               梁坚勇
# 1270  BARCLAYSBANKPLC  中国光大银行股份有限公司-易方达中证港股通医药卫生综合交易型开放式指数证券投资基金发起式联接基金
# 1271              李俞玮                                        华泰证券股份有限公司
# 1272              NaN                                               NaN
# 1273              NaN                                               NaN
#
#                                      第6名持有人名称  \
# 0                                         王剑鹏
# 1                                          殷庆
# 2                                         邓丹娃
# 3                                          杨岚
# 4                                         林小红
# ...                                       ...
# 1269                                      丁正阳
# 1270  中国民生银行股份有限公司-汇添富添福盈和稳健养老目标一年持有期混合型基金中基金
# 1271                        众诚汽车保险股份有限公司-自有资金
# 1272                                      NaN
# 1273                                      NaN
#
#                                      第7名持有人名称      第8名持有人名称  \
# 0                                          杨凯            唐亮
# 1                                         俞加益           李锡祥
# 2                              河南百瑞工程造价咨询有限公司            赵伟
# 3                                         应宇律           潘重光
# 4                                         钱晓健           徐静凤
# ...                                       ...           ...
# 1269                                      方翠云           薛智文
# 1270  上海浦东发展银行股份有限公司-汇添富聚焦经典一年持有期混合型基金中基金(FOF  工银安盛人寿保险有限公司
# 1271                               招商证券股份有限公司            阙俊
# 1272                                      NaN           NaN
# 1273                                      NaN           NaN
#
#                  第9名持有人名称                  第10名持有人名称    第11名持有人名称
# 0                     黄锦永                        顾少华          NaN
# 1                     张国强                         吴嫣          NaN
# 2                     宋协锦                         郑蕾          NaN
# 3                     于超银                        梁锟宜          NaN
# 4                      吴强                        林淑娟          NaN
# ...                   ...                        ...          ...
# 1269                   杨辉                         林魁          NaN
# 1270    百年人寿保险股份有限公司-平衡自营  新华资管-工商银行-新华资产-明仁八号资产管理产品  易方达基金管理有限公司
# 1271  北京华彬庄园绿色休闲健身俱乐部有限公司                        张雪川          NaN
# 1272                  NaN                        NaN          NaN
# 1273                  NaN                        NaN          NaN
#
# [1274 rows x 13 columns]

# %%
# name_data = load_data.iloc[:,2:]

# import pandas as pd

# # 假设您的 DataFrame 名为 load_data

# # 提取所有名字并合并到一个列表中
# all_holder_names = name_data.values.flatten().tolist()

# # 使用 set() 函数去除重复项
# unique_holder_names = list(set(all_holder_names))

# # 打印去除重复项后的所有名字
# for name in unique_holder_names:

# %%
import pandas as pd
# 假设您的 DataFrame 名为 load_data

# 创建空字典用于存储结果
holder_to_security_dict = {}

# 遍历 DataFrame，忽略最后一行（数据来源）
for i in range(len(load_data) - 1):
    row = load_data.iloc[i]
    security_short_name = row["证券简称"]
    holder_names = row[3:]  # 从第1名持有人名称开始

    for holder_name in holder_names:
        if pd.isna(holder_name):  # 跳过当前持有人名称，如果它是 NaN
            continue
        if len(holder_name) < 4: #过滤到个人
            continue
        if holder_name in holder_to_security_dict:
            holder_to_security_dict[holder_name].append(str(security_short_name))  # 将证券简称转换为字符串
        else:
            holder_to_security_dict[holder_name] = [str(security_short_name)]  # 将证券简称转换为字符串


# 打印结果字典
# for holder_name, security_short_names in holder_to_security_dict.items():
#     print(f"{holder_name}: {', '.join(security_short_names)}")

holder_df = pd.concat({holder_name: pd.Series(security_short_names)
                         for holder_name, security_short_names in holder_to_security_dict.items()},
                        axis=1)

# %%
# 假设您的 DataFrame 名为 load_data

# ...（之前的代码，构建 holder_to_security_dict 字典）
# ...（将字典转换为 DataFrame 的代码）

# licai_df = holder_df.loc[:, [col for col in holder_df.columns if '理财' in col]].T

# insurance_df = holder_df.loc[:, [col for col in holder_df.columns if '保险' in col]].T

# trust_df = holder_df.loc[:, [col for col in holder_df.columns if '信托' in col]].T

# security_df = holder_df.loc[:, [col for col in holder_df.columns if '证券股份' in col]].T

# MF_df = holder_df.loc[:, [col for col in holder_df.columns if '联接基金' in col]].T

# PE_df = holder_df.loc[:, [col for col in holder_df.columns if '私募' in col]].T

# futures_df = holder_df.loc[:, [col for col in holder_df.columns if '期货' in col]].T

# AM_df =  holder_df.loc[:, [col for col in holder_df.columns if '资产管理' in col and '基金' in col and '私募' not in col and ('银行' in col or '证券' in col)]].T

# pension_df = holder_df.loc[:, [col for col in holder_df.columns if '养老金' in col]].T

# FOF_df = holder_df.loc[:, [col for col in holder_df.columns if 'FOF' in col]].T

# yearfund_df = holder_df.loc[:, [col for col in holder_df.columns if '年金' in col]].T

# company_df = holder_df.loc[:, [col for col in holder_df.columns if '私募' not in col and 
# '证券' not in col and '保险' not in col and '资产管理' not in col and '年金' not in col and 
# 'FOF' not in col and '私募' not in col and '信托' not in col and '理财' not in col and
# '养老金' not in col and '投资' not in col and '银行' not in col and '资本' not in col and
# '财富' not in col and '期货' not in col and '基金' not in col and 'LOF' not in col
# ]].T

# with pd.ExcelWriter('holder_securities.xlsx') as writer:

#     holder_df.to_excel(writer, sheet_name='总表', index=False)

#     AM_df.to_excel(writer, sheet_name='公募资产专户', index=False)

#     FOF_df.to_excel(writer, sheet_name='公募FOF', index=False)

#     pension_df.to_excel(writer, sheet_name='公募养老金', index=False)

#     MF_df.to_excel(writer, sheet_name='联接基金', index=False)


#     licai_df.to_excel(writer, sheet_name='理财', index=False)

#     PE_df.to_excel(writer, sheet_name='私募', index=False)

#     trust_df.to_excel(writer, sheet_name='信托', index=False)

#     futures_df.to_excel(writer, sheet_name='期货', index=False)

#     insurance_df.to_excel(writer, sheet_name='保险', index=False)

#     security_df.to_excel(writer, sheet_name='证券', index=False)

#     yearfund_df.to_excel(writer, sheet_name='年金', index=False)

#     company_df.to_excel(writer, sheet_name='产业', index=False)

# 关闭 Excel Writer，保存文件

# %%
# insurance_df = holder_df.loc[:, [col for col in holder_df.columns if '保险' in col]].T
# insurance_df.reset_index(inplace=True)
# insurance_df.rename(columns={"index":"name"},inplace=True)
# insurance_df
# Out:
#                                         name                  0            1  \
# 0                   中国人民财产保险股份有限公司-传统-普通保险产品            富国中证军工A          NaN
# 1                        中国平安人寿保险股份有限公司-自有资金         招商上证港股通ETF  易方达深证100ETF
# 2                     中国平安人寿保险股份有限公司-分红-个险分红        易方达深证100ETF  汇添富中证800ETF
# 3                                 中荷人寿保险有限公司        易方达深证100ETF  汇添富中证800ETF
# 4    汇添富基金-中国人寿保险股份有限公司-分红险-汇添富基金国寿股份成长股票型组合        汇添富中证800ETF          NaN
# ..                                       ...                ...          ...
# 230                  泰康人寿保险股份有限公司-万能-个险万能(乙)     华泰柏瑞中证港股通科技ETF          NaN
# 231        泰康人寿保险股份有限公司-传统-普通保险产品-019L-CT001     华泰柏瑞中证港股通科技ETF          NaN
# 232          中国太平洋财产保险股份有限公司-传统-普通保险产品-013C-    华泰柏瑞南方东英恒生科技ETF          NaN
# 233                    长江财产保险股份有限公司-委托民生银行组合     银华恒生港股通中国科技ETF          NaN
# 234                        百年人寿保险股份有限公司-平衡自营  易方达中证港股通医药卫生综合ETF          NaN
#
#               2           3           4             5             6  \
# 0           NaN         NaN         NaN           NaN           NaN
# 1    华安上证180ETF  华夏沪深300ETF  嘉实沪深300ETF  国泰上证180金融ETF   华夏中证1000ETF
# 2     华夏上证50ETF  华安上证180ETF  华夏沪深300ETF    嘉实沪深300ETF  国泰上证180金融ETF
# 3    易方达中证红利ETF         NaN         NaN           NaN           NaN
# 4           NaN         NaN         NaN           NaN           NaN
# ..          ...         ...         ...           ...           ...
# 230         NaN         NaN         NaN           NaN           NaN
# 231         NaN         NaN         NaN           NaN           NaN
# 232         NaN         NaN         NaN           NaN           NaN
# 233         NaN         NaN         NaN           NaN           NaN
# 234         NaN         NaN         NaN           NaN           NaN
#
#                7             8  ...  353  354  355  356  357  358  359  360  \
# 0            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    天弘中证食品饮料ETF  天弘中证计算机主题ETF  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    华夏中证1000ETF   天弘中证食品饮料ETF  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..           ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 230          NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 231          NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 232          NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 233          NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 234          NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      361  362
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3    NaN  NaN
# 4    NaN  NaN
# ..   ...  ...
# 230  NaN  NaN
# 231  NaN  NaN
# 232  NaN  NaN
# 233  NaN  NaN
# 234  NaN  NaN
#
# [235 rows x 364 columns]

# %%
# insurance_df.set_index('name', inplace=True)
# 使用 melt 函数进行宽表转长表
melted_df = insurance_df.melt(id_vars=['name'],var_name='持有人', value_name='持有产品')

# 清理空值（NaN）
melted_df.dropna(inplace=True)

# 输出结果
melted_df.to_excel('meltdf.xlsx', index=True)

# %%
import pandas as pd
 
# 创建一个示例DataFrame
data = {
    'Date': ['2022-01-01', '2022-01-02', '2022-01-03'],
    'Tokyo': [15, 16, 12],
    'Paris': [10, 11, 13],
    'New York': [5, 8, 7]
}
 
df = pd.DataFrame(data)
 
# 使用melt函数进行宽格式转换为长格式
melted_df = pd.melt(df, id_vars=['Date'], var_name='City', value_name='Temperature')
 
print(melted_df)
# Out:
#          Date      City  Temperature
# 0  2022-01-01     Tokyo           15
# 1  2022-01-02     Tokyo           16
# 2  2022-01-03     Tokyo           12
# 3  2022-01-01     Paris           10
# 4  2022-01-02     Paris           11
# 5  2022-01-03     Paris           13
# 6  2022-01-01  New York            5
# 7  2022-01-02  New York            8
# 8  2022-01-03  New York            7
